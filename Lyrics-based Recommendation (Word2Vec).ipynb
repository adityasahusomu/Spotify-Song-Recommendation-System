# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from tqdm import tqdm
import re

import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
df_spotify_lyrics = pd.read_csv('spotify_millsongdata.csv')
df_spotify_lyrics.sample(5)
# Out:
#                artist                                   song  \
# 10147      Katy Perry                    Choose Your Battles
# 15588  Paul McCartney                           Just Because
# 5915       Faith Hill  Just To Hear You Say That You Love Me
# 15221         Outkast                                Babylon
# 7978     Hooverphonic                             Satin Doll
#
#                                                     link  \
# 10147    /k/katy+perry/choose+your+battles_21069179.html
# 15588       /p/paul+mccartney/just+because_20225762.html
# 5915   /f/faith+hill/just+to+hear+you+say+that+you+lo...
# 15221                   /o/outkast/babylon_20103839.html
# 7978            /h/hooverphonic/satin+doll_20065987.html
#
#                                                     text
# 10147  You are my hurt locker lover  \r\nKeep me walk...
# 15588  Well, well, well,  \r\nJust because you think ...
# 5915   If I could win your heart  \r\nIf you'd let me...
# 15221  I came into this world high as a bird  \r\nFro...
# 7978   This scary face on the wall  \r\nHis watch kil...

# %%
df_spotify_lyrics = df_spotify_lyrics.sample(10000)

# %%
df_spotify_lyrics.isnull().sum()
# Out:
# artist    0
# song      0
# link      0
# text      0
# dtype: int64

# %%
df_spotify_lyrics.duplicated().sum()
# Out:
# 0

# %%
df_spotify_lyrics.shape
# Out:
# (10000, 4)

# %%
df_spotify_lyrics.drop(columns=['link'], inplace=True)

# %%
df_spotify_lyrics.head()
# Out:
#                  artist                           song  \
# 51429         Scorpions         Every Minute Every Day
# 4400       Donna Summer                 I Will Survive
# 55242     Virgin Steele          Don't Close Your Eyes
# 31626  Enrique Iglesias                    Back To You
# 43631    Michael Bolton  We're Not Making Love Anymore
#
#                                                     text
# 51429  Well it seems that I was lost  \r\nIn intoxica...
# 4400   At First I was afriad I was petrified kept  \r...
# 55242  Don't go, don't leave me here alone  \r\nWith ...
# 31626  I've been down  \r\nI've been beat  \r\nI've b...
# 43631  Here we are, just goin' through the motions on...

# %%
df_spotify_lyrics.reset_index(drop=True, inplace=True)

# %%
df_spotify_lyrics.head()
# Out:
#              artist                           song  \
# 0         Scorpions         Every Minute Every Day
# 1      Donna Summer                 I Will Survive
# 2     Virgin Steele          Don't Close Your Eyes
# 3  Enrique Iglesias                    Back To You
# 4    Michael Bolton  We're Not Making Love Anymore
#
#                                                 text
# 0  Well it seems that I was lost  \r\nIn intoxica...
# 1  At First I was afriad I was petrified kept  \r...
# 2  Don't go, don't leave me here alone  \r\nWith ...
# 3  I've been down  \r\nI've been beat  \r\nI've b...
# 4  Here we are, just goin' through the motions on...

# %%
# Text Preprocessing:
# 1) lowercasing
# 2) Removing html tags and other expressions
# 3) Removing Puntuation
# 4) Spelling correction
# 5) Removing Stopwords
# 6) Lemmatization/Stemming
# 7) Tokenization

# %%
# lowercasing
df_spotify_lyrics['text'] = df_spotify_lyrics['text'].apply(lambda x: x.lower())

# %%
df_spotify_lyrics['text'][3]
# Out:
# "i've been down  \r\ni've been beat  \r\ni've been so that i could not speak  \r\ni've been so lost that i could not see  \r\ni wanted things that were out of reach  \r\nthen i found you and help me through and you show me  \r\nwhat to do  \r\nthat's why i'm comin' back to you  \r\n  \r\nlike a star that guides a ship across the ocean  \r\nthat's how your love can take me home back to you  \r\nand if i wish upon that star that someday i'll be where you are  \r\ncause i know that day is comin' soon yeah i'm comin' back to you  \r\n  \r\nyou've been alone but you did not show it  \r\nyou've been in pain when i did not know it  \r\nyou let me do what i needed to  \r\nyou where there when i needed you  \r\n  \r\nmighta let you down  \r\nmighta messed you round  \r\nbut you never change you point of view  \r\nthat's why i'm comin back to you.........\r\n\r\n"

# %%
# Removing html tags
import re
def remove_htmltags(txt):
    pattern = re.compile('<.*?>')
    return pattern.sub(r'',txt)

df_spotify_lyrics['text'] = df_spotify_lyrics['text'].apply(remove_htmltags)

# %%
def remove_regex(txt):
    pattern = re.compile('[\r\n]+')
    return pattern.sub(r'',txt)

df_spotify_lyrics['text'] = df_spotify_lyrics['text'].apply(remove_regex)

# %%
df_spotify_lyrics['text'][3]
# Out:
# "i've been down  i've been beat  i've been so that i could not speak  i've been so lost that i could not see  i wanted things that were out of reach  then i found you and help me through and you show me  what to do  that's why i'm comin' back to you    like a star that guides a ship across the ocean  that's how your love can take me home back to you  and if i wish upon that star that someday i'll be where you are  cause i know that day is comin' soon yeah i'm comin' back to you    you've been alone but you did not show it  you've been in pain when i did not know it  you let me do what i needed to  you where there when i needed you    mighta let you down  mighta messed you round  but you never change you point of view  that's why i'm comin back to you........."

# %%
# Removing punctuations
import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
exclude = string.punctuation
def remove_punc(txt):
    return txt.translate(str.maketrans('','', exclude))

df_spotify_lyrics['text'] = df_spotify_lyrics['text'].apply(remove_punc)

# %%
tqdm.pandas()
# spelling correction
from textblob import TextBlob
def spel_cor(txt):
    txtblb = TextBlob(txt)
    return txtblb.correct().string

df_spotify_lyrics['text'] = df_spotify_lyrics['text'].progress_apply(spel_cor)
# Out:
# 100%|███████████████████████████████████| 10000/10000 [6:44:52<00:00,  2.43s/it]

# %%
#stopwords
from nltk.corpus import stopwords
stopwords.words('english')

def remove_stopwords(txt):
    new_txt = []
    for w in txt.split():
        if w in stopwords.words('english'):
            new_txt.append('')
        else:
            new_txt.append(w)
    return ' '.join(new_txt)

df_spotify_lyrics['text'] = df_spotify_lyrics['text'].apply(remove_stopwords)

# %%
import nltk
from nltk.stem import WordNetLemmatizer

def lemmatize(text):
    wordnet_lemma = WordNetLemmatizer()
    punctuation = '?:!.,;'
    lem = []
    
    sent_word = nltk.word_tokenize(text)
    for w in sent_word:
        if w not in punctuation:
            lem.append(wordnet_lemma.lemmatize(w))
            
    return ' '.join(lem)

df_spotify_lyrics['text'] = df_spotify_lyrics['text'].progress_apply(lemmatize)
# Out:
# 100%|███████████████████████████████████| 10000/10000 [00:03<00:00, 3234.22it/s]

# %%
df_spotify_lyrics['text'][0]
# Out:
# 'well seems lost intoxicated night following trace ecstasy future past present alive like prisoner chained dream drowning feeling possession rule till morning kill creature night read lipstick message mirror truth gone realize without life like song without music without world wont need love every minute need love every day need love every minute need love come back stay well know lost nightmare life following flash fantasy feeling exploded id left reality behind addicted power dream without life like road lead nowhere without world wont feel need love every minute need love every day need love every minute need love come back stay'

# %%
from nltk import sent_tokenize
import gensim
from gensim.utils import simple_preprocess

story = []
for doc in df_spotify_lyrics['text']:
    raw_sent = sent_tokenize(doc)
    for sent in raw_sent:
        story.append(simple_preprocess(sent))

# %%
model = gensim.models.Word2Vec(
    window = 10,
    min_count = 2)

model.build_vocab(story)

# %%
model.train(story, total_examples=model.corpus_count, epochs= model.epochs)
# Out:
# (4685713, 5383345)

# %%
model.wv.index_to_key
# Out:
# ['love',
#  'dont',
#  'know',
#  'like',
#  'oh',
#  'time',
#  'got',
#  'go',
#  'give',
#  'one',
#  'get',
#  'want',
#  'see',
#  'come',
#  'baby',
#  'let',
#  'say',
#  'never',
#  'make',
#  'yeah',
#  'way',
#  'night',
#  'take',
#  'day',
#  'ill',
#  'cause',
#  'feel',
#  'heart',
#  'life',
#  'back',
#  'well',
#  'donna',
#  'need',
#  'away',
#  'right',
#  'could',
#  'girl',
#  'man',
#  'tell',
#  'thing',
#  'world',
#  'little',
#  'chorus',
#  'aunt',
#  'eye',
#  'good',
#  'think',
#  'said',
#  'long',
#  'keep',
#  'look',
#  'wont',
#  'home',
#  'would',
#  'around',
#  'every',
#  'nothing',
#  'still',
#  'mind',
#  'find',
#  'anna',
#  'always',
#  'dream',
#  'hand',
#  'hear',
#  'ever',
#  'light',
#  'cry',
#  'hey',
#  'hold',
#  'gutta',
#  'gone',
#  'much',
#  'believe',
#  'better',
#  'something',
#  'face',
#  'going',
#  'boy',
#  'la',
#  'everything',
#  'really',
#  'feeling',
#  'friend',
#  'turn',
#  'call',
#  'tonight',
#  'old',
#  'live',
#  'try',
#  'made',
#  'put',
#  'id',
#  'place',
#  'people',
#  'last',
#  'another',
#  'leave',
#  'head',
#  'alone',
#  'new',
#  'stay',
#  'run',
#  'hard',
#  'coming',
#  'show',
#  'word',
#  'blue',
#  'fall',
#  'even',
#  'looking',
#  'stop',
#  'left',
#  'true',
#  'please',
#  'name',
#  'inside',
#  'free',
#  'song',
#  'end',
#  'yes',
#  'god',
#  'wrong',
#  'big',
#  'ooh',
#  'soul',
#  'mine',
#  'without',
#  'kiss',
#  'forever',
#  'thought',
#  'walk',
#  'bad',
#  'sun',
#  'someone',
#  'living',
#  'lost',
#  'sweet',
#  'woman',
#  'lord',
#  'sky',
#  'change',
#  'care',
#  'done',
#  'lie',
#  'high',
#  'may',
#  'real',
#  'must',
#  'came',
#  'play',
#  'fire',
#  'sing',
#  'stand',
#  'remember',
#  'door',
#  'talk',
#  'child',
#  'rain',
#  'everybody',
#  'two',
#  'together',
#  'die',
#  'ah',
#  'star',
#  'trying',
#  'waiting',
#  'far',
#  'break',
#  'year',
#  'till',
#  'street',
#  'na',
#  'money',
#  'pain',
#  'tear',
#  'knew',
#  'start',
#  'hope',
#  'side',
#  'maybe',
#  'mean',
#  'em',
#  'many',
#  'town',
#  'wait',
#  'road',
#  'line',
#  'help',
#  'morning',
#  'getting',
#  'dance',
#  'round',
#  'wish',
#  'rock',
#  'enough',
#  'heaven',
#  'nobody',
#  'crazy',
#  'found',
#  'told',
#  'close',
#  'running',
#  'loving',
#  'hell',
#  'black',
#  'might',
#  'seen',
#  'kind',
#  'used',
#  'fool',
#  'cold',
#  'happy',
#  'smile',
#  'fly',
#  'watch',
#  'best',
#  'bring',
#  'first',
#  'matter',
#  'took',
#  'somebody',
#  'touch',
#  'today',
#  'though',
#  'lonely',
#  'roll',
#  'christmas',
#  'alright',
#  'move',
#  'open',
#  'arm',
#  'lose',
#  'game',
#  'goodby',
#  'talking',
#  'heard',
#  'else',
#  'sometimes',
#  'ride',
#  'young',
#  'deep',
#  'hurt',
#  'saw',
#  'dead',
#  'shine',
#  'sure',
#  'sound',
#  'body',
#  'forget',
#  'dark',
#  'wind',
#  'thinking',
#  'behind',
#  'whole',
#  'water',
#  'beat',
#  'work',
#  'king',
#  'city',
#  'alive',
#  'fight',
#  'darling',
#  'seems',
#  'understand',
#  'strong',
#  'along',
#  'part',
#  'sleep',
#  'reason',
#  'foot',
#  'went',
#  'ready',
#  'listen',
#  'angel',
#  'gun',
#  'anything',
#  'hit',
#  'chance',
#  'set',
#  'mamma',
#  'easy',
#  'lover',
#  'music',
#  'lot',
#  'guess',
#  'wall',
#  'voice',
#  'room',
#  'bout',
#  'ground',
#  'fine',
#  'calling',
#  'shit',
#  'standing',
#  'wonder',
#  'white',
#  'honey',
#  'moon',
#  'walking',
#  'babe',
#  'gave',
#  'blood',
#  'broken',
#  'hate',
#  'truth',
#  'making',
#  'sea',
#  'falling',
#  'land',
#  'fear',
#  'ask',
#  'mother',
#  'soon',
#  'burn',
#  'lady',
#  'late',
#  'house',
#  'pretty',
#  'car',
#  'fuck',
#  'upon',
#  'beautiful',
#  'lay',
#  'daddy',
#  'wanted',
#  'since',
#  'verse',
#  'river',
#  'hide',
#  'red',
#  'til',
#  'blow',
#  'cut',
#  'meet',
#  'jesus',
#  'next',
#  'miss',
#  'moment',
#  'drink',
#  'tried',
#  'bed',
#  'born',
#  'full',
#  'da',
#  'dog',
#  'death',
#  'son',
#  'air',
#  'tomorrow',
#  'loved',
#  'past',
#  'save',
#  'kill',
#  'burning',
#  'memory',
#  'fun',
#  'tree',
#  'promise',
#  'dear',
#  'wake',
#  'brother',
#  'everyone',
#  'party',
#  'whoa',
#  'afraid',
#  'low',
#  'hair',
#  'anymore',
#  'saying',
#  'sad',
#  'leaving',
#  'pay',
#  'pa',
#  'window',
#  'fast',
#  'follow',
#  'apart',
#  'hot',
#  'tired',
#  'trouble',
#  'slow',
#  'summer',
#  'taking',
#  'bitch',
#  'top',
#  'story',
#  'men',
#  'moving',
#  'earth',
#  'reach',
#  'use',
#  'shake',
#  'blind',
#  'singing',
#  'lip',
#  'lead',
#  'power',
#  'bit',
#  'train',
#  'mile',
#  'across',
#  'somewhere',
#  'holding',
#  'war',
#  'ring',
#  'floor',
#  'watching',
#  'ha',
#  'skin',
#  'sorry',
#  'shadow',
#  'turned',
#  'seem',
#  'cool',
#  'step',
#  'repeat',
#  'felt',
#  'hour',
#  'known',
#  'control',
#  'dancing',
#  'learn',
#  'shot',
#  'great',
#  'fucking',
#  'father',
#  'called',
#  'near',
#  'stone',
#  'rest',
#  'straight',
#  'tight',
#  'throw',
#  'drop',
#  'peace',
#  'secret',
#  'wild',
#  'million',
#  'le',
#  'sit',
#  'snow',
#  'darkness',
#  'mountain',
#  'yet',
#  'three',
#  'pray',
#  'clear',
#  'telling',
#  'dreaming',
#  'knee',
#  'grow',
#  'answer',
#  'drive',
#  'bright',
#  'read',
#  'nowhere',
#  'piece',
#  'gold',
#  'faith',
#  'sister',
#  'shining',
#  'speak',
#  'begin',
#  'shell',
#  'glory',
#  'catch',
#  'picture',
#  'joy',
#  'pull',
#  'met',
#  'bird',
#  'breath',
#  'future',
#  'strange',
#  'fell',
#  'cross',
#  'meant',
#  'cloud',
#  'looked',
#  'win',
#  'praise',
#  'damn',
#  'breaking',
#  'share',
#  'buy',
#  'within',
#  'different',
#  'walked',
#  'anyone',
#  'holy',
#  'working',
#  'hang',
#  'sitting',
#  'trust',
#  'minute',
#  'rise',
#  'nice',
#  'outside',
#  'warm',
#  'taken',
#  'ago',
#  'fallen',
#  'magic',
#  'caught',
#  'second',
#  'turning',
#  'bell',
#  'giving',
#  'mon',
#  'lying',
#  'laugh',
#  'plan',
#  'half',
#  'sick',
#  'empty',
#  'carry',
#  'belong',
#  'taste',
#  'worry',
#  'fade',
#  'whatever',
#  'space',
#  'sign',
#  'shoe',
#  'fill',
#  'rule',
#  'rather',
#  'bone',
#  'queen',
#  'poor',
#  'bye',
#  'started',
#  'shame',
#  'someday',
#  'blame',
#  'hill',
#  'almost',
#  'green',
#  'happen',
#  'not',
#  'spend',
#  'can',
#  'send',
#  'thank',
#  'chain',
#  'sight',
#  'funny',
#  'rolling',
#  'thousand',
#  'bridge',
#  'perfect',
#  'dying',
#  'phone',
#  'brain',
#  'everywhere',
#  'wide',
#  'rose',
#  'hanging',
#  'worth',
#  'cried',
#  'number',
#  'glad',
#  'playing',
#  'country',
#  'lucky',
#  'sorrow',
#  'choose',
#  'wing',
#  'oooh',
#  'finally',
#  'stranger',
#  'ocean',
#  'ran',
#  'freedom',
#  'grace',
#  'shall',
#  'ball',
#  'yesterday',
#  'winter',
#  'pick',
#  'devil',
#  'storm',
#  'already',
#  'breathe',
#  'de',
#  'mr',
#  'wine',
#  'front',
#  'wear',
#  'four',
#  'stick',
#  'treat',
#  'spirit',
#  'changed',
#  'losing',
#  'hundred',
#  'dawn',
#  'kick',
#  'smoke',
#  'hello',
#  'finger',
#  'scream',
#  'doubt',
#  'ten',
#  'swear',
#  'anyway',
#  'flame',
#  'broke',
#  'higher',
#  'track',
#  'shed',
#  'school',
#  'santa',
#  'glass',
#  'midnight',
#  'knock',
#  'mercy',
#  'five',
#  'none',
#  'ice',
#  'golden',
#  'mad',
#  'sin',
#  'key',
#  'missing',
#  'question',
#  'given',
#  'eat',
#  'luck',
#  'bottle',
#  'guitar',
#  'guy',
#  'cover',
#  'dirty',
#  'shout',
#  'sleeping',
#  'ear',
#  'become',
#  'searching',
#  'paper',
#  'check',
#  'scared',
#  'everyday',
#  'somehow',
#  'wheel',
#  'mouth',
#  'quite',
#  'family',
#  'died',
#  'desire',
#  'doctor',
#  'flower',
#  'middle',
#  'closer',
#  'plain',
#  'wed',
#  'case',
#  'beyond',
#  'learned',
#  'evening',
#  'flow',
#  'corner',
#  'needed',
#  'prayer',
#  'book',
#  'hut',
#  'simple',
#  'write',
#  'push',
#  'pride',
#  'clock',
#  'dry',
#  'wife',
#  'wave',
#  'class',
#  'di',
#  'slowly',
#  'heat',
#  'held',
#  'sand',
#  'waste',
#  'riding',
#  'news',
#  'yea',
#  'small',
#  'silver',
#  'loud',
#  'bar',
#  'human',
#  'beside',
#  'letter',
#  'count',
#  'later',
#  'mistake',
#  'leaf',
#  'point',
#  'bet',
#  'diamond',
#  'keeping',
#  'kept',
#  'merry',
#  'lift',
#  'edge',
#  'precious',
#  'knowing',
#  'band',
#  'stuck',
#  'sense',
#  'forgive',
#  'sunshine',
#  'brought',
#  'style',
#  'safe',
#  'heavy',
#  'began',
#  'evil',
#  'act',
#  'realize',
#  'york',
#  'circle',
#  'crowd',
#  'paradise',
#  'bow',
#  'problem',
#  'clothes',
#  'brown',
#  'slip',
#  'mirror',
#  'others',
#  'growing',
#  'rich',
#  'brings',
#  'color',
#  'ahead',
#  'folk',
#  'bear',
#  'week',
#  'single',
#  'filled',
#  'radio',
#  'seven',
#  'build',
#  'rocking',
#  'shoot',
#  'twice',
#  'bound',
#  'stood',
#  'played',
#  'laughing',
#  'mess',
#  'killing',
#  'law',
#  'silence',
#  'fat',
#  'endless',
#  'cat',
#  'whisper',
#  'freak',
#  'hero',
#  'welcome',
#  'insane',
#  'west',
#  'short',
#  'regret',
#  'strength',
#  'state',
#  'flying',
#  'thrill',
#  'pop',
#  'instead',
#  'highway',
#  'choice',
#  'dollar',
#  'clean',
#  'brand',
#  'mystery',
#  'rhythm',
#  'price',
#  'longer',
#  'crime',
#  'horse',
#  'hole',
#  'south',
#  'wherever',
#  'beauty',
#  'romance',
#  'jump',
#  'screaming',
#  'loose',
#  'lonesome',
#  'danger',
#  'hallelujah',
#  'pretend',
#  'ho',
#  'asked',
#  'age',
#  'awake',
#  'jack',
#  'sugar',
#  'early',
#  'ease',
#  'okay',
#  'driving',
#  'bang',
#  'missed',
#  'wit',
#  'shoulder',
#  'weather',
#  'stopped',
#  'anybody',
#  'field',
#  'stuff',
#  'mo',
#  'happiness',
#  'steal',
#  'silent',
#  'job',
#  'spent',
#  'fact',
#  'sail',
#  'beneath',
#  'hiding',
#  'hook',
#  'john',
#  'sunday',
#  'hoping',
#  'lived',
#  'loneliness',
#  'moonlight',
#  'rhyme',
#  'crawl',
#  'return',
#  'ship',
#  'card',
#  'thunder',
#  'message',
#  'deal',
#  'ghost',
#  'club',
#  'join',
#  'fate',
#  'quick',
#  'dust',
#  'wondering',
#  'anywhere',
#  'shore',
#  'drunk',
#  'vision',
#  'smell',
#  'shut',
#  'spell',
#  'lovely',
#  'passing',
#  'changing',
#  'saved',
#  'wash',
#  'kid',
#  'survive',
#  'cap',
#  'table',
#  'tall',
#  'bottom',
#  'view',
#  'scene',
#  'steel',
#  'due',
#  'stare',
#  'fit',
#  'bag',
#  'machine',
#  'whenever',
#  'sell',
#  'happened',
#  'lock',
#  'dumb',
#  'dress',
#  'neck',
#  'mary',
#  'kissed',
#  'fighting',
#  'climb',
#  'blowing',
#  'wonderful',
#  'fever',
#  'bend',
#  'leg',
#  'beginning',
#  'hat',
#  'birch',
#  'wood',
#  'toe',
#  'race',
#  'noise',
#  'passed',
#  'grown',
#  'special',
#  'fantasy',
#  'hurry',
#  'grave',
#  'paint',
#  'drinking',
#  'surprise',
#  'proud',
#  'spring',
#  'trip',
#  'soldier',
#  'seeing',
#  'weak',
#  'supposed',
#  'distance',
#  'breeze',
#  'stronger',
#  'lifetime',
#  'tender',
#  'shaking',
#  'drug',
#  'disappear',
#  'boot',
#  'ok',
#  'scar',
#  'crack',
#  'sang',
#  'harder',
#  'fair',
#  'bought',
#  'church',
#  'america',
#  'sex',
#  'couple',
#  'worship',
#  'co',
#  'dare',
#  'yellow',
#  'business',
#  'mighty',
#  'underneath',
#  'hood',
#  'flesh',
#  'explain',
#  'pleasure',
#  'daughter',
#  'hungry',
#  'escape',
#  'hoe',
#  'grab',
#  'park',
#  'season',
#  'seemed',
#  'grass',
#  'chill',
#  'sunk',
#  'boat',
#  'beer',
#  'bullet',
#  'enemy',
#  'happens',
#  'rainbow',
#  'double',
#  'paid',
#  'bill',
#  'sent',
#  'murder',
#  'believing',
#  'rush',
#  'six',
#  'clown',
#  'feed',
#  'path',
#  'master',
#  'mi',
#  'prove',
#  'mission',
#  'woke',
#  'papa',
#  'page',
#  'cruel',
#  'forgot',
#  'locked',
#  'surely',
#  'thou',
#  'note',
#  'history',
#  'wrapped',
#  'smiling',
#  'comfort',
#  'spinning',
#  'system',
#  'monday',
#  'older',
#  'tune',
#  'fame',
#  'asking',
#  'least',
#  'pocket',
#  'gate',
#  'listening',
#  'raise',
#  'hotel',
#  'knocking',
#  ...]

# %%
model.wv['touch']
# Out:
# array([ 0.85556954,  0.80403876, -0.5799133 ,  2.157911  , -0.06291752,
#        -0.79848593, -0.5518212 ,  1.5456254 , -1.6095718 , -0.30140883,
#         1.799928  ,  1.7779415 , -2.9499729 ,  0.42505038, -0.44563225,
#         1.4839821 ,  0.4025599 , -0.70364213,  0.23643167, -0.20767981,
#        -0.10041285, -0.36842972, -0.70606595,  0.11227178,  0.2000336 ,
#        -1.4328538 , -1.8491517 ,  2.6237078 , -2.7602255 ,  0.33889124,
#        -1.0337923 ,  0.89929885, -1.1444167 ,  0.1320258 , -0.32441503,
#        -0.95940113,  1.0633048 , -0.19023094,  1.1773819 ,  1.0901102 ,
#         0.03482237, -2.0500684 ,  0.79589605,  0.2434444 ,  1.230167  ,
#         0.82516223,  0.29196653, -0.7240777 ,  2.2009106 ,  1.5828495 ,
#        -1.9538383 ,  0.33239785, -0.68160844,  0.76618373,  0.0786422 ,
#         0.63139015,  0.8393283 , -1.7127674 , -0.9891505 ,  0.32632843,
#         0.07847245, -1.0099546 ,  1.4549843 , -1.6710777 , -0.57812476,
#         3.5078712 ,  1.2378346 ,  1.1661932 , -1.7118393 ,  1.019485  ,
#         0.15495552,  0.51821154,  1.1561154 , -0.05694215, -1.6730101 ,
#         0.11879099,  0.92158955,  1.481591  ,  0.7585896 , -0.5125626 ,
#         1.5400944 , -0.46836877,  0.30110806,  0.421369  , -0.38393784,
#         0.11679513,  0.45936552,  0.4588425 ,  0.08002835, -0.08138651,
#         1.6218089 , -1.7613192 ,  0.0701286 ,  0.5733041 ,  1.6371425 ,
#         1.6607703 ,  0.46695754,  0.96827936, -1.0953026 ,  0.22686598],
#       dtype=float32)

# %%
def document_vector(doc):
    doc = [word for word in doc.split() if word in model.wv.index_to_key]
    return np.mean(model.wv[doc], axis=0)

# When you set axis=0, the operation is applied column-wise across the rows of the array.
#.      It operates along the first axis, which is typically the vertical axis in a 2D array.
# When you use axis=1 in a NumPy function like np.mean(), the operation is applied row-wise across the columns of the array. 
#       In other words, it operates along the second axis, which is typically the horizontal axis in a 2D array.

# %%
document_vector(df_spotify_lyrics['text'][0])
# Out:
# array([ 0.04750453, -0.8294919 ,  0.43110248,  0.65020746, -0.21500133,
#        -0.82213116,  0.00151731,  0.828463  , -0.8376896 , -0.4398146 ,
#         0.35101175,  0.58949494, -0.7812034 ,  0.54321176,  0.12932776,
#        -0.03060713,  0.2531629 ,  0.06347384, -0.67183137, -0.31927574,
#         0.6649782 , -0.22541367,  0.61443675,  0.1640586 ,  0.42775196,
#        -0.13882816, -0.4441272 ,  0.7546618 , -0.6600979 ,  0.27395803,
#         0.08682233, -0.44627452,  0.4670278 , -0.5980858 , -0.15199226,
#        -0.08926564,  0.64209473,  0.42930746, -0.49154812, -0.55687356,
#         0.39556727,  0.32033512,  0.02601005,  0.09679578,  0.30347863,
#         0.02589785, -0.4853221 ,  0.01142661,  0.36417407,  0.42228287,
#        -0.254038  , -0.02409875, -0.6274225 ,  0.33309883,  0.19318515,
#        -0.01718237, -0.22036767,  0.03245667, -0.06796312,  0.44734555,
#        -0.10104336, -0.08076698,  0.86316717, -0.00814562, -0.56034225,
#         0.83093876,  0.36929598,  0.6575853 , -0.57968515,  0.65214187,
#        -0.4730208 ,  0.42208984,  0.2638399 , -0.09488522, -0.03632453,
#        -0.41966376,  0.556355  ,  0.88588035, -0.16252518, -0.48643827,
#         0.37142193,  0.00772075,  0.02003077,  0.02715086, -0.33037758,
#         0.20346057, -0.02831139, -0.07992337, -0.5629309 ,  0.96290857,
#         0.56528836, -0.10322724, -0.3190944 , -0.1103786 ,  0.55336493,
#         0.27092868,  0.5222386 , -0.2774702 ,  0.07284854, -0.13498919],
#       dtype=float32)

# %%
dox = []
for d in tqdm(df_spotify_lyrics['text'].values):
    dox.append(document_vector(d))
# Out:
# 100%|███████████████████████████████████| 10000/10000 [00:07<00:00, 1261.90it/s]

# %%
dox = np.array(dox)

# %%
dox.shape
# Out:
# (10000, 100)

# %%
from sklearn.metrics.pairwise import cosine_similarity
similar_wv = cosine_similarity(dox)

# %%
similar_wv[2]                           # cosine similarity of 3rd review with every review
# Out:
# array([0.8122626 , 0.8392058 , 1.0000002 , ..., 0.5569336 , 0.8094466 ,
#        0.71388286], dtype=float32)

# %%
df_spotify_lyrics[(df_spotify_lyrics['song']=='I Will Survive') & (df_spotify_lyrics['artist'] == 'Donna Summer')]
# Out:
#          artist            song  \
# 1  Donna Summer  I Will Survive
#
#                                                 text
# 1  first afraid petrified kept think going live w...

# %%
def recommender_wv(song_name, artist_name):
    idx = df_spotify_lyrics[(df_spotify_lyrics['song'] == song_name) & 
                            (df_spotify_lyrics['artist']== artist_name)].index[0]
    
    # distance is a list of tuples. Each tuple contains index and the similiarity score
    distance = sorted(list(enumerate(similar_wv[idx])), reverse=True, key=lambda x: x[1])
    
    songs = []
    for s_id in distance[1:10]:
        songs.append(df_spotify_lyrics.iloc[s_id[0]].song)
    
    return songs

# %%
recommender_wv('I Will Survive', 'Donna Summer')
# Out:
# ['I Will Survive',
#  'No Looking Back',
#  "It's Over",
#  "Mickey's Malt Liquor",
#  "Don't It",
#  'Locomotive',
#  'Shaking You',
#  'Walk Away From Love',
#  'Spinning The Wheel']

# %%
import pickle
pickle.dump(similar_wv, open('similarity_lyrics_wv', 'wb'))
pickle.dump(df_spotify_lyrics, open('df_spotify_lyrics','wb'))
